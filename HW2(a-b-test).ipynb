# %% [markdown]
# # Домашнее задание №2

# %% [markdown]
# ## Задание 1
# Сделайте приоритезацию гипотез из предыдущего урока с помощью ICE

# %% [markdown]
# |   Гипотеза	|   Влияние	| Уверенность  	|   Лёгкость	|   Баллы	|
# |---	|---	|---	|---	|---	|
# | Если сделать фиксируемую скидку на каждый следующий месяц подписки (аля КБМ для осаго), то можно увеличить LTV на 20%, по причине того, что выгоднее будет продолжать подписку, чем обрывать серию скидок.  	|   10	|   9	|   3	|   270	|
# |   Внендрение планировщика постов и сообщений для платной подписки, увеличит конверсию на 1%, потому что не придётся обращаться к сторонним сервисам.	|   5	|   3	|   2	|   30	|
# |   Введение режима "без контента", полностью убирающая всё кроме текста, увеличит среднее время проведённое в мессенджере на 15 минут, потому что будет выгоднее для пользователей с лимитом на интернет, либо с плохим доступом.	|   6	|   6	|   4	|   144	|
# |   Встроенныё кошелёк и внутренняя оплата для платной подписки увеличит конверсию перехода в платную подписку на 5%, потому что сервис уберёт всех посредников, для ведения бизнеса внутри сети.	|   8	|   7	|   4	|   224	|
# |   Скидка на платную подписку в 50%, за 3 привлечённых новых пользователя, увеличит конверсию в платную подписку на 2% и DAU на 1%, из-за притока новых пользователей по приглашениям.	|   5	|   7	|   7	|   245	|

# %% [markdown]
# ## Задание 2
# Составьте шаблон дизайна эксперимента для гипотезы, которая набрала больше всего баллов в практическом задании предыдущего урока

# %% [markdown]
# **Гипотеза:**
# > Если сделать фиксируемую скидку на каждый следующий месяц подписки (аля КБМ для осаго), то можно увеличить LTV на 20%, по причине того, что выгоднее будет продолжать подписку, чем обрывать серию скидок.
#
# **Что делаем в каждой из групп:**
# * 1 группа: условия стандартные
# * 2 группа: Предоставляем накопительную скидку в 5%, за каждый месяц продления, но не более 45%.
#
# **На каких пользователях тестируем:**
#
# Новые пользователи сервиса
#
# **Метрики:**
#
# LTV, средняя продолжительность подписки, churn rate, процент пользователей включивших автопродление подписки(автоподписку).
